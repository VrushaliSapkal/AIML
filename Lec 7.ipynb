# %%
# !pip install simple-image-download==0.4
# Out:
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12082 sha256=31c79ee6d6e397dc89903d7b6c18a44e42e158eae1ab07adaf5ae7ff8035f54a
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\d7\d9\89\a3f31c76ff6d51dc3b1575628f59afe59e4ceae3f2748cd7ad
# Successfully built progressbar
# ...

# %%
from simple_image_download import simple_image_download as simp

# %%
search_queries=['Diary Milk images','Kitkat images','5 star images']
for query in search_queries:
    print(query)
    response=simp.simple_image_download
    response().download(query,50)
# Out:
# [                                                                        ]   0%
# Diary Milk images
# [========================================================================] 100%
# [                                                                        ]   0%
# Kitkat images
# [========================================================================] 100%
# [                                                                        ]   0%
# 5 star images
# [========================================================================] 100%

# %%
# !pip install seaborn

# %%
import seaborn as sns 
sns.distplot([0,1,2,3,4,5,6,7])                          #bellcub         #dist=distribution plot       #uniformly distributed
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
import seaborn as sns 
sns.distplot([8,0,3,9,5,7,1])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
import seaborn as sns 
sns.distplot([8,0,3,9,5,7,1],hist=False)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
#eda-explainatory data analysis

# %%
sns.barplot([8,0,3,9,5,7,1])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
import numpy as np
x=np.array([1,2,3,4])
y=np.array([4,5,6,7])
sns.barplot(x,y,color='Yellow')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.barplot(x,y,palette='rocket')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.barplot(x,y,palette='pastel')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.barplot(x,y,palette='bright')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.barplot(x,y,palette='colorblind')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
#iris

iris=sns.load_dataset('iris')
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris=sns.load_dataset('titanic')
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
iris.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Countplot
sns.countplot(data=iris,x='alive',color='Hotpink',palette='pastel')
# Out:
# <AxesSubplot:xlabel='alive', ylabel='count'>

# %%
sns.countplot(data=iris,y='alive',color='Hotpink',palette='pastel')
# Out:
# <AxesSubplot:xlabel='count', ylabel='alive'>

# %%
sns.countplot(data=iris,x='alive',hue='class',color='Hotpink',palette='pastel')
# Out:
# <AxesSubplot:xlabel='alive', ylabel='count'>

# %%
titanic=sns.load_dataset('titanic')
sns.barplot(data=titanic,x='alive',y='age')
# Out:
# <AxesSubplot:xlabel='alive', ylabel='age'>

# %%
import matplotlib.pyplot as plt
plt.legend(title="Titanic")
sns.barplot(data=titanic,x='alive',y='age')
# Out:
# No handles with labels found to put in legend.
# <AxesSubplot:xlabel='alive', ylabel='age'>

# %%
ax=titanic.plot(figsize=(15,8),title="Titanic Dataset")
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
titanic['pclass'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
titanic['pclass'].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
titanic['pclass'].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='pclass'>

# %%
titanic['pclass'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic['pclass'].plot(kind='hist',orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
titanic=sns.load_dataset('titanic')
titanic.plot.bar()
# Out:
# <AxesSubplot:>

# %%
titanic.plot.barh()
# Out:
# <AxesSubplot:>

# %%
titanic.plot.scatter(x='pclass',y='age',c='fare')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
titanic.plot.scatter(x='pclass',y='age',c='fare',label='Almas')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
titanic.plot.hexbin(x='pclass',y='age',label='Almas',gridsize=5)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
titanic.plot.pie=('y=age')
