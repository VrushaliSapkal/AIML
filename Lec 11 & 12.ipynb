# %%
#18-3-22

import pandas as pd

# %%
df=pd.read_csv('creditcard.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import seaborn as sns

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 284802    False
# 284803    False
# 284804    False
# 284805    False
# 284806    False
# Length: 284807, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop(columns=['Time'],inplace=True)

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
x=df.drop('Class',1)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_10512/123554873.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   x=df.drop('Class',1)

# %%
x.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0  0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Amount
# ...

# %%
y=df.Class

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 283726, dtype: int64

# %%
x=df.iloc[:,df.columns!='Class']

# %%
x
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V20       V21  \
# ...

# %%
#standarization-required for wide range

# %%
#mean-0

# %%
#standard derivation-1

# %%
from sklearn.model_selection import train_test_split

x_test, x_train, y_test, y_train=train_test_split(x,y,test_size=0.2,random_state=5)

# %%
x_train
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 121580 -0.396288  0.802373  1.615882  1.468026 -0.282496  0.432082  0.417594
# 265472  1.909423 -0.368523 -3.150923 -0.603011  2.517304  3.209951 -0.457625
# 234990  1.985101 -0.126672 -1.210636  0.291810 -0.091382 -1.057818  0.128493
# 116860 -1.086874  1.434534  1.089271 -0.323588 -0.324947 -1.355154  0.501191
# 125215 -0.949734  0.242471  0.193362 -1.666638  2.359518  3.462452  0.634579
# ...          ...       ...       ...       ...       ...       ...       ...
# 222518 -6.427437 -9.458758  0.789114 -2.030686  6.481861  0.263965 -4.923430
# 119166  1.259378 -1.527217  0.566969 -1.412461 -1.774041 -0.260950 -1.241862
# 167199  2.149687 -0.615148 -1.792341 -0.663043 -0.075483 -0.869555  0.059361
# 226781  2.015959  0.618374 -2.932867  0.789768  0.832589 -1.948723  0.678057
# 183178 -0.365907  0.655729  0.051279 -0.792987  0.674098 -0.544720  0.877726
#
# ...

# %%
y_test
# Out:
# 137407    0
# 127546    0
# 49498     0
# 18208     0
# 195321    0
#          ..
# 137101    0
# 233290    0
# 125082    0
# 20534     0
# 18701     0
# Name: Class, Length: 226980, dtype: int64

# %%
#standarization-required for wide range
from sklearn import preprocessing
scaler=preprocessing.StandardScaler().fit(x_train)
x_train_scaled=scaler.transform(x_train)

# %%
import numpy as np
np.mean(x_train,axis=1)
# Out:
# 121580     1.920584
# 265472     2.199135
# 234990     0.823757
# 116860     0.099490
# 125215     4.616549
#             ...
# 222518    15.565515
# 119166     4.238207
# 167199     0.745715
# 226781     0.908417
# 183178     0.205667
# Length: 56746, dtype: float64

# %%
np.mean(x_train_scaled,axis=1)
# Out:
# array([ 0.1521807 ,  0.09468454,  0.12783319, ..., -0.14265924,
#        -0.07207502, -0.145888  ])

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Time'}>,
#         <AxesSubplot:title={'center':'V1'}>,
#         <AxesSubplot:title={'center':'V2'}>,
#         <AxesSubplot:title={'center':'V3'}>,
#         <AxesSubplot:title={'center':'V4'}>,
#         <AxesSubplot:title={'center':'V5'}>],
#        [<AxesSubplot:title={'center':'V6'}>,
#         <AxesSubplot:title={'center':'V7'}>,
#         <AxesSubplot:title={'center':'V8'}>,
#         <AxesSubplot:title={'center':'V9'}>,
#         <AxesSubplot:title={'center':'V10'}>,
#         <AxesSubplot:title={'center':'V11'}>],
#        [<AxesSubplot:title={'center':'V12'}>,
#         <AxesSubplot:title={'center':'V13'}>,
#         <AxesSubplot:title={'center':'V14'}>,
#         <AxesSubplot:title={'center':'V15'}>,
#         <AxesSubplot:title={'center':'V16'}>,
#         <AxesSubplot:title={'center':'V17'}>],
#        [<AxesSubplot:title={'center':'V18'}>,
#         <AxesSubplot:title={'center':'V19'}>,
# ...

# %%
data.hist(figsize=(15,15),color='Green')
# Out:
# array([[<AxesSubplot:title={'center':'Time'}>,
#         <AxesSubplot:title={'center':'V1'}>,
#         <AxesSubplot:title={'center':'V2'}>,
#         <AxesSubplot:title={'center':'V3'}>,
#         <AxesSubplot:title={'center':'V4'}>,
#         <AxesSubplot:title={'center':'V5'}>],
#        [<AxesSubplot:title={'center':'V6'}>,
#         <AxesSubplot:title={'center':'V7'}>,
#         <AxesSubplot:title={'center':'V8'}>,
#         <AxesSubplot:title={'center':'V9'}>,
#         <AxesSubplot:title={'center':'V10'}>,
#         <AxesSubplot:title={'center':'V11'}>],
#        [<AxesSubplot:title={'center':'V12'}>,
#         <AxesSubplot:title={'center':'V13'}>,
#         <AxesSubplot:title={'center':'V14'}>,
#         <AxesSubplot:title={'center':'V15'}>,
#         <AxesSubplot:title={'center':'V16'}>,
#         <AxesSubplot:title={'center':'V17'}>],
#        [<AxesSubplot:title={'center':'V18'}>,
#         <AxesSubplot:title={'center':'V19'}>,
# ...

# %%
sns.heatmap(df.corr().round(2),square=True,cmap='RdYlGn',annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LogisticRegression

# %%
regression=LogisticRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
regression.score(x_train,y_train)
# Out:
# 0.9995241955380115

# %%
regression.score(x_test,y_test)
# Out:
# 0.999242223984492

# %%
regression.score(x_train_scaled,y_train)
# Out:
# 0.9942022345187326

# %%
y_pred=regression.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
test_accuracy=accuracy_score(y_test,y_pred)
print("Test accuracy is {}".format(test_acc*100))
# Out:
# Test accuracy is 99.9242223984492

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    226599
#            1       0.85      0.67      0.75       381
#
#     accuracy                           1.00    226980
#    macro avg       0.92      0.83      0.87    226980
# weighted avg       1.00      1.00      1.00    226980

# %%
#Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(cm,annot=True,fmt='d',cmap="Blues")   #cmap=color screen
# Out:
# <AxesSubplot:>

# %%
df1=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
print(df1.head(25))
# Out:
#         Actual  Predicted
# 137407       0          0
# 127546       0          0
# 49498        0          0
# 18208        0          0
# 195321       0          0
# 205667       0          0
# 97776        0          0
# 210055       0          0
# 36132        0          0
# 123473       0          0
# 93523        0          0
# 207576       0          0
# 34881        0          0
# 234625       0          0
# 215682       0          0
# 101593       0          0
# 85256        0          0
# 214742       0          0
# 119445       0          0
# 170437       0          0
# 132097       0          0
# 259306       0          0
# 171257       0          0
# 164029       0          0
# 137035       0          0

# %%
from sklearn import metrics
print("ROC Curve Evaluation")
# Out:
# ROC Curve Evaluation

# %%
fpr,tpr,_=(metrics.roc_curve(y_test,y_pred))
auc=metrics.roc_auc_score(y_test,y_pred)
plt.plot(fpr,tpr,label='data,auc='+str(auc))
plt.legend(loc=4)
plt.show()

# %%
#19-3-22

# %%
#        z=x-mean/standard deviation

# %%
import numpy as np
data=[[6,2],[4,2],[6,4],[8,2]]

# %%
a=np.array(data)

# %%
np.std(a,axis=0)
# Out:
# array([1.41421356, 0.8660254 ])

# %%
np.mean(a,axis=0)
# Out:
# array([6. , 2.5])

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(data)
# Out:
# StandardScaler()

# %%
print(scaler.mean_)
# Out:
# [6.  2.5]

# %%
z=scaler.transform(data)

# %%
#n=165       Predicted        Predicted
#            (No)               (Yes)
    
    
#Actual      50  TN           10   FP
#no

#Actual      5   FN           100  TP
#Yes

# %%
#     Accuracy=TP+TN/N                                                                                         0.9090

#     Misclassification Rate / Error Rate=    FP+FN/N        OR    1-Accuracy                                  0.909

#Recall/True Positive Rate

#     Recall / True Positive Rate / Sensitivity of Classification = TP/TP+FN     OR     TP/Actual Yes          0.95

#     Precision=TP/TP+FP      OR     TP/Predicted Yes                                                          0.909 

#     F-measure=2*Recall*Precision Recall+Precision

# %%
#ROC Curve

#     TPR(True +ve Curve)=TP/TP=FN

#     FPR(False +ve Curve=FP=FP=TN

#AUC(Area Under Curve)

# %%
#No activation fun for linear regression
#Activation fun for logistic regression-     sigmod function=1/1+e^(mx+c)         0 to 1
