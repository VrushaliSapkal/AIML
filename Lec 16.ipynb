# %%
#23-3-22

# %%
#linear regression - seaborn-Ridge regression

# %%
import pandas as pd
data= pd.read_csv("D:\Boston.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
data.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
data.shape
# Out:
# (506, 15)

# %%
data.head(20)
# Out:
#     Unnamed: 0     crim    zn  indus  chas    nox     rm    age     dis  rad  \
# 0            1  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1
# 1            2  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2
# 2            3  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2
# 3            4  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3
# 4            5  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3
# 5            6  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3
# 6            7  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5
# 7            8  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5
# 8            9  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5
# 9           10  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5
# 10          11  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
data.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# crim          0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# age           0
# dis           0
# rad           0
# tax           0
# ptratio       0
# black         0
# lstat         0
# medv          0
# dtype: int64

# %%
data=data.drop(columns=["Unnamed: 0"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  black    506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
import numpy as np
data.zn.replace(0,np.nan,inplace=True)
data.chas.replace(0,np.nan,inplace=True)

# %%
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31   NaN  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   NaN   7.07   NaN  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   NaN   7.07   NaN  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   NaN   2.18   NaN  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   NaN   2.18   NaN  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       134 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     35 non-null     float64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  black    506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
data.isnull().sum()/len(data)*100
# Out:
# crim        0.000000
# zn         73.517787
# indus       0.000000
# chas       93.083004
# nox         0.000000
# rm          0.000000
# age         0.000000
# dis         0.000000
# rad         0.000000
# tax         0.000000
# ptratio     0.000000
# black       0.000000
# lstat       0.000000
# medv        0.000000
# dtype: float64

# %%
data.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
data=data.drop("chas",1)
data=data.drop("zn",1)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_14404/3730742837.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data=data.drop("chas",1)
# C:\Users\user\AppData\Local\Temp/ipykernel_14404/3730742837.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data=data.drop("zn",1)

# %%
data.head()
# Out:
#       crim  indus    nox     rm   age     dis  rad  tax  ptratio   black  \
# 0  0.00632   2.31  0.538  6.575  65.2  4.0900    1  296     15.3  396.90
# 1  0.02731   7.07  0.469  6.421  78.9  4.9671    2  242     17.8  396.90
# 2  0.02729   7.07  0.469  7.185  61.1  4.9671    2  242     17.8  392.83
# 3  0.03237   2.18  0.458  6.998  45.8  6.0622    3  222     18.7  394.63
# 4  0.06905   2.18  0.458  7.147  54.2  6.0622    3  222     18.7  396.90
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   indus    506 non-null    float64
#  2   nox      506 non-null    float64
#  3   rm       506 non-null    float64
#  4   age      506 non-null    float64
#  5   dis      506 non-null    float64
#  6   rad      506 non-null    int64
#  7   tax      506 non-null    int64
#  8   ptratio  506 non-null    float64
#  9   black    506 non-null    float64
#  10  lstat    506 non-null    float64
#  11  medv     506 non-null    float64
# dtypes: float64(10), int64(2)
# memory usage: 47.6 KB

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'crim'}>,
#         <AxesSubplot:title={'center':'indus'}>,
#         <AxesSubplot:title={'center':'nox'}>],
#        [<AxesSubplot:title={'center':'rm'}>,
#         <AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'dis'}>],
#        [<AxesSubplot:title={'center':'rad'}>,
#         <AxesSubplot:title={'center':'tax'}>,
#         <AxesSubplot:title={'center':'ptratio'}>],
#        [<AxesSubplot:title={'center':'black'}>,
#         <AxesSubplot:title={'center':'lstat'}>,
#         <AxesSubplot:title={'center':'medv'}>]], dtype=object)

# %%
data.hist(figsize=(15,15),color="black")
# Out:
# array([[<AxesSubplot:title={'center':'crim'}>,
#         <AxesSubplot:title={'center':'indus'}>,
#         <AxesSubplot:title={'center':'nox'}>],
#        [<AxesSubplot:title={'center':'rm'}>,
#         <AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'dis'}>],
#        [<AxesSubplot:title={'center':'rad'}>,
#         <AxesSubplot:title={'center':'tax'}>,
#         <AxesSubplot:title={'center':'ptratio'}>],
#        [<AxesSubplot:title={'center':'black'}>,
#         <AxesSubplot:title={'center':'lstat'}>,
#         <AxesSubplot:title={'center':'medv'}>]], dtype=object)

# %%
data.head(20)
# Out:
#        crim  indus    nox     rm    age     dis  rad  tax  ptratio   black  \
# 0   0.00632   2.31  0.538  6.575   65.2  4.0900    1  296     15.3  396.90
# 1   0.02731   7.07  0.469  6.421   78.9  4.9671    2  242     17.8  396.90
# 2   0.02729   7.07  0.469  7.185   61.1  4.9671    2  242     17.8  392.83
# 3   0.03237   2.18  0.458  6.998   45.8  6.0622    3  222     18.7  394.63
# 4   0.06905   2.18  0.458  7.147   54.2  6.0622    3  222     18.7  396.90
# 5   0.02985   2.18  0.458  6.430   58.7  6.0622    3  222     18.7  394.12
# 6   0.08829   7.87  0.524  6.012   66.6  5.5605    5  311     15.2  395.60
# 7   0.14455   7.87  0.524  6.172   96.1  5.9505    5  311     15.2  396.90
# 8   0.21124   7.87  0.524  5.631  100.0  6.0821    5  311     15.2  386.63
# 9   0.17004   7.87  0.524  6.004   85.9  6.5921    5  311     15.2  386.71
# 10  0.22489   7.87  0.524  6.377   94.3  6.3467    5  311     15.2  392.52
# ...

# %%
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.heatmap(data.corr().round(2),square=True,cmap='RdYlGn',annot=True)
# rad and tax are strongly corelated to each other hence drop rad
# Out:
# <AxesSubplot:>

# %%
data.head()
# Out:
#       crim  indus    nox     rm   age     dis  rad  tax  ptratio   black  \
# 0  0.00632   2.31  0.538  6.575  65.2  4.0900    1  296     15.3  396.90
# 1  0.02731   7.07  0.469  6.421  78.9  4.9671    2  242     17.8  396.90
# 2  0.02729   7.07  0.469  7.185  61.1  4.9671    2  242     17.8  392.83
# 3  0.03237   2.18  0.458  6.998  45.8  6.0622    3  222     18.7  394.63
# 4  0.06905   2.18  0.458  7.147  54.2  6.0622    3  222     18.7  396.90
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
#x= data.drop(['rad','medv'],1)

# %%
x= data.drop(['rad','medv'],1)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_14404/454575626.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   x= data.drop(['rad','medv'],1)

# %%
x
# Out:
#         crim  indus    nox     rm   age     dis  tax  ptratio   black  lstat
# 0    0.00632   2.31  0.538  6.575  65.2  4.0900  296     15.3  396.90   4.98
# 1    0.02731   7.07  0.469  6.421  78.9  4.9671  242     17.8  396.90   9.14
# 2    0.02729   7.07  0.469  7.185  61.1  4.9671  242     17.8  392.83   4.03
# 3    0.03237   2.18  0.458  6.998  45.8  6.0622  222     18.7  394.63   2.94
# 4    0.06905   2.18  0.458  7.147  54.2  6.0622  222     18.7  396.90   5.33
# ..       ...    ...    ...    ...   ...     ...  ...      ...     ...    ...
# 501  0.06263  11.93  0.573  6.593  69.1  2.4786  273     21.0  391.99   9.67
# 502  0.04527  11.93  0.573  6.120  76.7  2.2875  273     21.0  396.90   9.08
# 503  0.06076  11.93  0.573  6.976  91.0  2.1675  273     21.0  396.90   5.64
# 504  0.10959  11.93  0.573  6.794  89.3  2.3889  273     21.0  393.45   6.48
# 505  0.04741  11.93  0.573  6.030  80.8  2.5050  273     21.0  396.90   7.88
#
# [506 rows x 10 columns]

# %%
data.head()
# Out:
#       crim  indus    nox     rm   age     dis  rad  tax  ptratio   black  \
# 0  0.00632   2.31  0.538  6.575  65.2  4.0900    1  296     15.3  396.90
# 1  0.02731   7.07  0.469  6.421  78.9  4.9671    2  242     17.8  396.90
# 2  0.02729   7.07  0.469  7.185  61.1  4.9671    2  242     17.8  392.83
# 3  0.03237   2.18  0.458  6.998  45.8  6.0622    3  222     18.7  394.63
# 4  0.06905   2.18  0.458  7.147  54.2  6.0622    3  222     18.7  396.90
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
y=data['medv']

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
y.shape
# Out:
# (506,)

# %%
x.shape
# Out:
# (506, 10)

# %%
#from sklearn.linear_model import Ridge

# %%
#model=Ridge(alpha=0.1)

# %%
#from sklearn.linear_model import Lasso

# %%
#model=Lasso(alpha=1.0)

# %%
from sklearn.linear_model import ElasticNet

# %%
model=ElasticNet(alpha=0.1)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)
y_train
# Out:
# 478    14.6
# 26     16.6
# 7      27.1
# 492    20.1
# 108    19.8
#        ...
# 106    19.5
# 270    21.1
# 348    24.5
# 435    13.4
# 102    18.6
# Name: medv, Length: 339, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
regression =LinearRegression()
#regression.fit(X_train,y_train)
#y_pred=regression.predict(X_test)
#y_pred
#y_test

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regression.predict(x_test)
y_pred
#y_test
# Out:
# array([28.97210458, 32.50535305, 19.46939914, 26.37850445, 18.60006593,
#        24.24294982, 17.72880818, 15.14237801, 22.50909882, 21.46674024,
#        21.13723465, 18.76099833, -6.52891857, 23.17893562, 19.25975504,
#        26.20431565, 18.6584965 ,  4.9740689 , 39.04341097, 17.38778755,
#        27.13427242, 29.19599469, 11.14958133, 24.80106725, 17.71556698,
#        15.23275797, 24.50910502, 14.42433883, 19.01185844, 20.25157539,
#        22.13324095, 25.65196645, 25.74281496, 18.02643535, 15.926727  ,
#        18.6530259 , 31.86236031, 19.95726231, 20.95244313, 25.89090036,
#        14.63873585, 29.87743924, 40.11374622, 18.54773903, 27.9135355 ,
#        16.71393616, 13.9901974 , 27.18096398, 19.89006197, 31.34287621,
#        21.56405488, 33.69523961, 15.99265768, 27.41318231, 39.48229014,
#        23.03227619, 18.65346196, 30.79467497, 25.42488599, 12.4966439 ,
#        22.08882314, 28.52234575, 31.93862142, 16.91381802, 22.21899601,
# ...

# %%
y_test
# Out:
# 173    23.6
# 274    32.4
# 491    13.6
# 72     22.8
# 452    16.1
#        ...
# 110    21.7
# 321    23.1
# 265    22.8
# 29     21.0
# 262    48.8
# Name: medv, Length: 167, dtype: float64

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
print ("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 23.15244397543244

# %%
print("MSE : ",mean_absolute_error(y_test,y_pred))
# Out:
# MSE :  3.37073466113832

# %%
print ("R2_score : " ,r2_score(y_test,y_pred))
# Out:
# R2_score :  0.6940684419745684

# %%
regression.score(x_test,y_test)
# Out:
# 0.6940684419745684

# %%
import matplotlib.pyplot as plt
plt.scatter(y_pred,y_test)

# %%
import pickle 
# %matplotlib inline 
filename = "BostonLinearRegressioModel.pickle"
pickle.dump(regression,open(filename,'wb'))

# %%
loaded_model=pickle.load(open(filename,'rb'))
result = loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.6940684419745684
