# %%
#12-3-22

# %%
import pandas as pd
data=pd.read_csv('boston.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
data.shape
# Out:
# (506, 15)

# %%
data.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
#  13  lstat       506 non-null    float64
#  14  medv        506 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %%
data.isnull().sum()          #to check null values
# Out:
# Unnamed: 0    0
# crim          0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# age           0
# dis           0
# rad           0
# tax           0
# ptratio       0
# black         0
# lstat         0
# medv          0
# dtype: int64

# %%
#how to remove columns

data.drop(columns=['Unnamed: 0'])
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
data.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
data=data.drop(columns=['Unnamed: 0'])  #to delete it... assign it

# %%
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data.info
# Out:
# <bound method DataFrame.info of         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# ...

# %%
import numpy as np
data.zn.replace(0,np.nan,inplace=True)
data.info
# Out:
# <bound method DataFrame.info of         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   NaN   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   NaN   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   NaN   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   NaN   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   NaN  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   NaN  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   NaN  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   NaN  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   NaN  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# ...

# %%
data.isnull().sum()/len(data)*100               #to check float data type
# Out:
# crim        0.000000
# zn         73.517787
# indus       0.000000
# chas        0.000000
# nox         0.000000
# rm          0.000000
# age         0.000000
# dis         0.000000
# rad         0.000000
# tax         0.000000
# ptratio     0.000000
# black       0.000000
# lstat       0.000000
# medv        0.000000
# dtype: float64

# %%
data=data.drop('zn',1)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_21124/383551745.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data=data.drop('zn',1)

# %%
data=data.drop('chas',1)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_21124/3891588663.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data=data.drop('chas',1)

# %%
data.head()
# Out:
#       crim  indus    nox     rm   age     dis  rad  tax  ptratio   black  \
# 0  0.00632   2.31  0.538  6.575  65.2  4.0900    1  296     15.3  396.90
# 1  0.02731   7.07  0.469  6.421  78.9  4.9671    2  242     17.8  396.90
# 2  0.02729   7.07  0.469  7.185  61.1  4.9671    2  242     17.8  392.83
# 3  0.03237   2.18  0.458  6.998  45.8  6.0622    3  222     18.7  394.63
# 4  0.06905   2.18  0.458  7.147  54.2  6.0622    3  222     18.7  396.90
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
data.isnull().sum()/len(data)*100
# Out:
# crim       0.0
# indus      0.0
# nox        0.0
# rm         0.0
# age        0.0
# dis        0.0
# rad        0.0
# tax        0.0
# ptratio    0.0
# black      0.0
# lstat      0.0
# medv       0.0
# dtype: float64

# %%
data.columns
# Out:
# Index(['crim', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio',
#        'black', 'lstat', 'medv'],
#       dtype='object')

# %%
data.shape
# Out:
# (506, 12)

# %%
data.hist()                #histogram
# Out:
# array([[<AxesSubplot:title={'center':'crim'}>,
#         <AxesSubplot:title={'center':'indus'}>,
#         <AxesSubplot:title={'center':'nox'}>],
#        [<AxesSubplot:title={'center':'rm'}>,
#         <AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'dis'}>],
#        [<AxesSubplot:title={'center':'rad'}>,
#         <AxesSubplot:title={'center':'tax'}>,
#         <AxesSubplot:title={'center':'ptratio'}>],
#        [<AxesSubplot:title={'center':'black'}>,
#         <AxesSubplot:title={'center':'lstat'}>,
#         <AxesSubplot:title={'center':'medv'}>]], dtype=object)

# %%
data.hist(figsize=(15,15),color='Green')            #to see histogram in big size
# Out:
# array([[<AxesSubplot:title={'center':'crim'}>,
#         <AxesSubplot:title={'center':'indus'}>,
#         <AxesSubplot:title={'center':'nox'}>],
#        [<AxesSubplot:title={'center':'rm'}>,
#         <AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'dis'}>],
#        [<AxesSubplot:title={'center':'rad'}>,
#         <AxesSubplot:title={'center':'tax'}>,
#         <AxesSubplot:title={'center':'ptratio'}>],
#        [<AxesSubplot:title={'center':'black'}>,
#         <AxesSubplot:title={'center':'lstat'}>,
#         <AxesSubplot:title={'center':'medv'}>]], dtype=object)

# %%
data.head(20)
# Out:
#        crim  indus    nox     rm    age     dis  rad  tax  ptratio   black  \
# 0   0.00632   2.31  0.538  6.575   65.2  4.0900    1  296     15.3  396.90
# 1   0.02731   7.07  0.469  6.421   78.9  4.9671    2  242     17.8  396.90
# 2   0.02729   7.07  0.469  7.185   61.1  4.9671    2  242     17.8  392.83
# 3   0.03237   2.18  0.458  6.998   45.8  6.0622    3  222     18.7  394.63
# 4   0.06905   2.18  0.458  7.147   54.2  6.0622    3  222     18.7  396.90
# 5   0.02985   2.18  0.458  6.430   58.7  6.0622    3  222     18.7  394.12
# 6   0.08829   7.87  0.524  6.012   66.6  5.5605    5  311     15.2  395.60
# 7   0.14455   7.87  0.524  6.172   96.1  5.9505    5  311     15.2  396.90
# 8   0.21124   7.87  0.524  5.631  100.0  6.0821    5  311     15.2  386.63
# 9   0.17004   7.87  0.524  6.004   85.9  6.5921    5  311     15.2  386.71
# 10  0.22489   7.87  0.524  6.377   94.3  6.3467    5  311     15.2  392.52
# ...

# %%
#seaborn
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
sns.heatmap(data.corr().round(2),square=True,cmap='RdYlGn',annot=True)        #correlation    #round figure #Colur scheme  #show values so use annot
#rad & tax are correlated hence drop rad or tax
# Out:
# <AxesSubplot:>

# %%
data.head()
# Out:
#       crim  indus    nox     rm   age     dis  rad  tax  ptratio   black  \
# 0  0.00632   2.31  0.538  6.575  65.2  4.0900    1  296     15.3  396.90
# 1  0.02731   7.07  0.469  6.421  78.9  4.9671    2  242     17.8  396.90
# 2  0.02729   7.07  0.469  7.185  61.1  4.9671    2  242     17.8  392.83
# 3  0.03237   2.18  0.458  6.998  45.8  6.0622    3  222     18.7  394.63
# 4  0.06905   2.18  0.458  7.147  54.2  6.0622    3  222     18.7  396.90
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
X=data.drop(['rad','medv'],1)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_21124/1425751715.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X=data.drop(['rad','medv'],1)

# %%
data.head()
# Out:
#       crim  indus    nox     rm   age     dis  rad  tax  ptratio   black  \
# 0  0.00632   2.31  0.538  6.575  65.2  4.0900    1  296     15.3  396.90
# 1  0.02731   7.07  0.469  6.421  78.9  4.9671    2  242     17.8  396.90
# 2  0.02729   7.07  0.469  7.185  61.1  4.9671    2  242     17.8  392.83
# 3  0.03237   2.18  0.458  6.998  45.8  6.0622    3  222     18.7  394.63
# 4  0.06905   2.18  0.458  7.147  54.2  6.0622    3  222     18.7  396.90
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
Y=data['medv'].values

# %%
Y
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
X
# Out:
#         crim  indus    nox     rm   age     dis  tax  ptratio   black  lstat
# 0    0.00632   2.31  0.538  6.575  65.2  4.0900  296     15.3  396.90   4.98
# 1    0.02731   7.07  0.469  6.421  78.9  4.9671  242     17.8  396.90   9.14
# 2    0.02729   7.07  0.469  7.185  61.1  4.9671  242     17.8  392.83   4.03
# 3    0.03237   2.18  0.458  6.998  45.8  6.0622  222     18.7  394.63   2.94
# 4    0.06905   2.18  0.458  7.147  54.2  6.0622  222     18.7  396.90   5.33
# ..       ...    ...    ...    ...   ...     ...  ...      ...     ...    ...
# 501  0.06263  11.93  0.573  6.593  69.1  2.4786  273     21.0  391.99   9.67
# 502  0.04527  11.93  0.573  6.120  76.7  2.2875  273     21.0  396.90   9.08
# 503  0.06076  11.93  0.573  6.976  91.0  2.1675  273     21.0  396.90   5.64
# 504  0.10959  11.93  0.573  6.794  89.3  2.3889  273     21.0  393.45   6.48
# 505  0.04741  11.93  0.573  6.030  80.8  2.5050  273     21.0  396.90   7.88
#
# [506 rows x 10 columns]

# %%
X.shape
# Out:
# (506, 10)

# %%
Y.shape  #means 1 column
# Out:
# (506,)

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split(X,Y,test_size=0.33,random_state=42)
# Out:
# [         crim  indus    nox     rm   age     dis  tax  ptratio   black  lstat
#  478  10.23300  18.10  0.614  6.185  96.7  2.1705  666     20.2  379.70  18.03
#  26    0.67191   8.14  0.538  5.813  90.3  4.6820  307     21.0  376.88  14.81
#  7     0.14455   7.87  0.524  6.172  96.1  5.9505  311     15.2  396.90  19.15
#  492   0.11132  27.74  0.609  5.983  83.5  2.1099  711     20.1  396.90  13.35
#  108   0.12802   8.56  0.520  6.474  97.1  2.4329  384     20.9  395.24  12.27
#  ..        ...    ...    ...    ...   ...     ...  ...      ...     ...    ...
#  106   0.17120   8.56  0.520  5.836  91.9  2.2110  384     20.9  395.67  18.66
#  270   0.29916   6.96  0.464  5.856  42.1  4.4290  223     18.6  388.65  13.00
#  348   0.01501   2.01  0.435  6.635  29.7  8.3440  280     17.0  390.94   5.99
#  435  11.16040  18.10  0.740  6.629  94.6  2.1247  666     20.2  109.85  23.27
#  102   0.22876   8.56  0.520  6.405  85.4  2.7147  384     20.9   70.80  10.63
#
# ...

# %%
X_train, x_test, Y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# %%
X_train
# Out:
#          crim  indus     nox     rm   age     dis  tax  ptratio   black  lstat
# 182   0.09103   2.46  0.4880  7.155  92.2  2.7006  193     17.8  394.12   4.82
# 155   3.53501  19.58  0.8710  6.152  82.6  1.7455  403     14.7   88.01  15.02
# 280   0.03578   3.33  0.4429  7.820  64.5  4.6947  216     14.9  387.31   3.76
# 126   0.38735  25.65  0.5810  5.613  95.6  1.7572  188     19.1  359.29  27.26
# 329   0.06724   3.24  0.4600  6.333  17.2  5.2146  430     16.9  375.21   7.34
# ..        ...    ...     ...    ...   ...     ...  ...      ...     ...    ...
# 106   0.17120   8.56  0.5200  5.836  91.9  2.2110  384     20.9  395.67  18.66
# 270   0.29916   6.96  0.4640  5.856  42.1  4.4290  223     18.6  388.65  13.00
# 348   0.01501   2.01  0.4350  6.635  29.7  8.3440  280     17.0  390.94   5.99
# 435  11.16040  18.10  0.7400  6.629  94.6  2.1247  666     20.2  109.85  23.27
# 102   0.22876   8.56  0.5200  6.405  85.4  2.7147  384     20.9   70.80  10.63
#
# [379 rows x 10 columns]

# %%
Y_train
# Out:
# array([37.9, 15.6, 45.4, 15.7, 22.6, 14.5, 18.7, 17.8, 16.1, 20.6, 31.6,
#        29.1, 15.6, 17.5, 22.5, 19.4, 19.3,  8.5, 20.6, 17. , 17.1, 14.5,
#        50. , 14.3, 12.6, 28.7, 21.2, 19.3, 23.1, 19.1, 25. , 33.4,  5. ,
#        29.6, 18.7, 21.7, 23.1, 22.8, 21. , 48.8, 14.6, 16.6, 27.1, 20.1,
#        19.8, 21. , 41.3, 23.2, 20.4, 18.5, 29.4, 36.4, 24.4, 11.8, 13.8,
#        12.3, 17.8, 33.1, 26.7, 13.4, 14.4, 50. , 22. , 19.9, 23.8, 17.5,
#        12.7,  5.6, 31.1, 26.2, 19.4, 16.7, 13.8, 22.9, 15.3, 27.5, 36.1,
#        22.9, 24.5, 25. , 50. , 34.9, 31.7, 24.1, 22.1, 14.1, 42.8, 19.3,
#        32.2, 26.4, 21.8, 21.7,  8.3, 46.7, 43.1, 31.5, 10.5, 16.7, 20. ,
#        33.3, 17.8, 50. , 20.5, 23.2, 13.1, 19.6, 22.8, 28.7, 30.7, 22.9,
#        21.9, 23.9, 32.7, 24.3, 21.5, 24.6,  8.5, 26.4, 23.1, 15. ,  8.8,
#        19.3, 23.9, 24.7, 19.8, 23.8, 13.3, 29. , 27.1, 34.6, 13.3, 15.6,
#        12.5, 14.6, 11. , 24.8, 17.3,  8.1, 21.4, 15.6, 23.3, 32. , 38.7,
# ...

# %%
x_test
# Out:
#          crim  indus    nox     rm    age     dis  tax  ptratio   black  lstat
# 173   0.09178   4.05  0.510  6.416   84.1  2.6463  296     16.6  395.50   9.04
# 274   0.05644   6.41  0.447  6.758   32.9  4.0776  254     17.6  396.90   3.53
# 491   0.10574  27.74  0.609  5.983   98.8  1.8681  711     20.1  390.11  18.07
# 72    0.09164  10.81  0.413  6.065    7.8  5.2873  305     19.2  390.91   5.52
# 452   5.09017  18.10  0.713  6.297   91.8  2.3682  666     20.2  385.09  17.27
# ..        ...    ...    ...    ...    ...     ...  ...      ...     ...    ...
# 418  73.53410  18.10  0.679  5.957  100.0  1.8026  666     20.2   16.45  20.62
# 117   0.15098  10.01  0.547  6.021   82.6  2.7474  432     17.8  394.51  10.30
# 42    0.14150   6.91  0.448  6.169    6.6  5.7209  233     17.9  383.37   5.81
# 322   0.35114   7.38  0.493  6.041   49.9  4.7211  287     19.6  396.90   7.70
# 347   0.01870   4.15  0.429  6.516   27.7  8.5353  351     17.9  392.43   6.36
#
# [127 rows x 10 columns]

# %%
y_test
# Out:
# array([23.6, 32.4, 13.6, 22.8, 16.1, 20. , 17.8, 14. , 19.6, 16.8, 21.5,
#        18.9,  7. , 21.2, 18.5, 29.8, 18.8, 10.2, 50. , 14.1, 25.2, 29.1,
#        12.7, 22.4, 14.2, 13.8, 20.3, 14.9, 21.7, 18.3, 23.1, 23.8, 15. ,
#        20.8, 19.1, 19.4, 34.7, 19.5, 24.4, 23.4, 19.7, 28.2, 50. , 17.4,
#        22.6, 15.1, 13.1, 24.2, 19.9, 24. , 18.9, 35.4, 15.2, 26.5, 43.5,
#        21.2, 18.4, 28.5, 23.9, 18.5, 25. , 35.4, 31.5, 20.2, 24.1, 20. ,
#        13.1, 24.8, 30.8, 12.7, 20. , 23.7, 10.8, 20.6, 20.8,  5. , 20.1,
#        48.5, 10.9,  7. , 20.9, 17.2, 20.9,  9.7, 19.4, 29. , 16.4, 25. ,
#        25. , 17.1, 23.2, 10.4, 19.6, 17.2, 27.5, 23. , 50. , 17.9,  9.6,
#        17.2, 22.5, 21.4, 12. , 19.9, 19.4, 13.4, 18.2, 24.6, 21.1, 24.7,
#         8.7, 27.5, 20.7, 36.2, 31.6, 11.7, 39.8, 13.9, 21.8, 23.7, 17.6,
#        24.4,  8.8, 19.2, 25.3, 20.4, 23.1])

# %%
#linear regression
#prediction & classification(binary)

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()           #model-regression

# %%
regression.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=regression.predict(x_test)

# %%
y_pred
# Out:
# array([29.12052737, 32.42406633, 19.34663973, 25.90844062, 18.57368856,
#        24.2966386 , 17.9995269 , 15.65900852, 22.34254164, 21.53287384,
#        21.45935839, 18.95682586, -6.88682131, 23.12388161, 19.2259102 ,
#        26.15822355, 19.10146631,  4.83065319, 39.34234448, 17.38363736,
#        26.90833081, 29.12005427, 11.57379834, 25.08142148, 17.47136335,
#        14.88022819, 24.10488582, 14.32595353, 19.36619154, 20.16092169,
#        22.14255162, 25.65430251, 26.04715288, 17.36309907, 15.91477504,
#        18.43627162, 32.14276391, 19.87002385, 21.07366776, 25.54831171,
#        14.63340701, 30.23082039, 40.52194515, 18.24287711, 28.02113756,
#        16.46800645, 14.26498948, 26.89102854, 19.77109992, 31.28029438,
#        21.62113733, 33.74571016, 16.48246913, 27.58625558, 39.64528118,
#        22.59706867, 18.61618257, 30.77985821, 25.50843838, 12.57362629,
#        22.27842603, 28.68513216, 31.61751922, 16.48227798, 21.94166969,
# ...

# %%
y_test
# Out:
# array([23.6, 32.4, 13.6, 22.8, 16.1, 20. , 17.8, 14. , 19.6, 16.8, 21.5,
#        18.9,  7. , 21.2, 18.5, 29.8, 18.8, 10.2, 50. , 14.1, 25.2, 29.1,
#        12.7, 22.4, 14.2, 13.8, 20.3, 14.9, 21.7, 18.3, 23.1, 23.8, 15. ,
#        20.8, 19.1, 19.4, 34.7, 19.5, 24.4, 23.4, 19.7, 28.2, 50. , 17.4,
#        22.6, 15.1, 13.1, 24.2, 19.9, 24. , 18.9, 35.4, 15.2, 26.5, 43.5,
#        21.2, 18.4, 28.5, 23.9, 18.5, 25. , 35.4, 31.5, 20.2, 24.1, 20. ,
#        13.1, 24.8, 30.8, 12.7, 20. , 23.7, 10.8, 20.6, 20.8,  5. , 20.1,
#        48.5, 10.9,  7. , 20.9, 17.2, 20.9,  9.7, 19.4, 29. , 16.4, 25. ,
#        25. , 17.1, 23.2, 10.4, 19.6, 17.2, 27.5, 23. , 50. , 17.9,  9.6,
#        17.2, 22.5, 21.4, 12. , 19.9, 19.4, 13.4, 18.2, 24.6, 21.1, 24.7,
#         8.7, 27.5, 20.7, 36.2, 31.6, 11.7, 39.8, 13.9, 21.8, 23.7, 17.6,
#        24.4,  8.8, 19.2, 25.3, 20.4, 23.1])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
print('MSE',mean_squared_error(y_test,y_pred))
# Out:
# MSE 25.2921005404369

# %%
print('MSE',mean_absolute_error(y_test,y_pred))
# Out:
# MSE 3.305642558793442

# %%
print('R2_score',r2_score(y_test,y_pred))
# Out:
# R2_score 0.6388243298155938

# %%
regression.score(x_test,y_pred)
# Out:
# 1.0

# %%
regression.score(x_test,y_pred)
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test,y_pred)

# %%
#Pickle-to save model & use whenever want

# %%
#Pickling

# %%
import pickle
# %matplotlib inline

# %%
filename="BostonLinearRegressionModel.pickle"

# %%
pickle.dump(regression,open(filename,'wb'))        #wb- write,byte

# %%
loaded_model=pickle.load(open (filename,'rb'))

# %%
result=loaded_model.score(x_test,y_test)

# %%
print(result)
# Out:
# 0.6388243298155938

# %%
#Overfitting & Underfitting

# %%
#linear-prediction(regression), Logistic-classification

# %%
#overfitting - training the data,testing not proper

# %%
#Underfitting - Training,testing not proper

# %%
#continuous - Numerical              #categorical - Logistic regression

# %%
#Logistic regression-tries to cover most of points

# %%
#sigmoid fun-:Activation fun=1/1+e^-z where z=mx+c
#y=mx+c     -:LR
